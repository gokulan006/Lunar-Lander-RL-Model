# %%
# !apt install swig cmake
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# swig is already the newest version (4.0.2-1ubuntu1).
# cmake is already the newest version (3.22.1-1ubuntu1.22.04.2).
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.

# %%
# !pip install -r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt
# Out:
# Requirement already satisfied: stable-baselines3==2.0.0a5 in /usr/local/lib/python3.11/dist-packages (from -r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (2.0.0a5)
# Requirement already satisfied: swig in /usr/local/lib/python3.11/dist-packages (from -r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 2)) (4.3.0)
# Requirement already satisfied: huggingface_sb3 in /usr/local/lib/python3.11/dist-packages (from -r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4)) (3.0)
# Requirement already satisfied: gymnasium[box2d] in /usr/local/lib/python3.11/dist-packages (from -r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 3)) (0.28.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (1.26.4)
# Requirement already satisfied: torch>=1.11 in /usr/local/lib/python3.11/dist-packages (from stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (2.5.1+cu124)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (3.1.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (3.10.0)
# Requirement already satisfied: jax-jumpy>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 3)) (1.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 3)) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 3)) (0.0.4)
# Requirement already satisfied: box2d-py==2.3.5 in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 3)) (2.3.5)
# Requirement already satisfied: pygame==2.1.3 in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d]->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 3)) (2.1.3)
# Requirement already satisfied: huggingface-hub~=0.8 in /usr/local/lib/python3.11/dist-packages (from huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4)) (0.27.1)
# Requirement already satisfied: pyyaml~=6.0 in /usr/local/lib/python3.11/dist-packages (from huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4)) (6.0.2)
# Requirement already satisfied: wasabi in /usr/local/lib/python3.11/dist-packages (from huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4)) (1.1.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4)) (3.17.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4)) (2024.10.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4)) (24.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4)) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4)) (4.67.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (3.1.5)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (12.3.1.170)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (12.4.127)
# Requirement already satisfied: triton==3.1.0 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (3.1.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=1.11->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=1.11->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (4.55.7)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=1.11->stable-baselines3==2.0.0a5->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 1)) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->huggingface-hub~=0.8->huggingface_sb3->-r https://raw.githubusercontent.com/huggingface/deep-rl-class/main/notebooks/unit1/requirements-unit1.txt (line 4)) (2024.12.14)

# %%
# !sudo apt-get update
# !sudo apt-get install -y python3-opengl
# !apt install ffmpeg
# !apt install xvfb
# !pip3 install pyvirtualdisplay
# Out:
# Get:1 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:2 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:3 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:5 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:6 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Hit:10 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Fetched 257 kB in 2s (160 kB/s)
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# python3-opengl is already the newest version (3.1.5+dfsg-1).
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.12).
# 0 upgraded, 0 newly installed, 0 to remove and 22 not upgraded.
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.11/dist-packages (3.0)

# %%
import os
os.kill(os.getpid(), 9)

# %%
# Virtual display
from pyvirtualdisplay import Display

virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# %% [markdown]
# ## Import the packages

# %%
import gymnasium

from huggingface_sb3 import load_from_hub,package_to_hub
from huggingface_hub import notebook_login

from stable_baselines3 import PPO
from stable_baselines3.common.env_util import make_vec_env
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.monitor import Monitor

# %%
import gymnasium as gym

# First create our environment called LunarLander-v2
env=gym.make("LunarLander-v2")

# reset the environment
obsevation,info=env.reset()

for _ in range(20):
  action=env.action_space.sample()
  print("Action taken ",action)

  # Do the action in the environment and get next_state,reward,terminated,truncated and info
  observation,reward,terminated,truncated,info=env.step(action)

  if truncated or terminated:
    print("Reset the Environment")
    observation,info=env.reset()

env.close()
# Out:
# Action taken  0
# Action taken  1
# Action taken  1
# Action taken  2
# Action taken  3
# Action taken  1
# Action taken  2
# Action taken  2
# Action taken  2
# Action taken  1
# Action taken  2
# Action taken  2
# Action taken  0
# Action taken  2
# Action taken  0
# Action taken  3
# Action taken  3
# Action taken  1
# Action taken  3
# Action taken  0

# %%
env=gym.make("LunarLander-v2")
env.reset()
print("_____OBSERVATION SPACE_____ \n")
print("Observation Space Shape", env.observation_space.shape)
print("Sample observation", env.observation_space.sample())
# Out:
# _____OBSERVATION SPACE_____
#
# Observation Space Shape (8,)
# Sample observation [-4.0928264  89.98002    -3.430067    2.2846181   3.0368326  -4.9877734
#   0.850166    0.13226007]

# %%
print("\n _____ACTION SPACE_____ \n")
print("Action Space Shape", env.action_space.n)
print("Action Space Sample", env.action_space.sample())
# Out:
#  _____ACTION SPACE_____
#
# Action Space Shape 4
# Action Space Sample 1

# %%
# Create the environment
env=make_vec_env('LunarLander-v2',n_envs=16)

# %%
model=PPO(policy="MlpPolicy",
          env=env,
          n_steps=1024,
          batch_size=64,
          n_epochs=4,
          gamma=0.999,
          gae_lambda=0.98,
          ent_coef=0.01,
          verbose=1)
# Out:
# Using cuda device

# %% [markdown]
# ## Train the PPO agent

# %%
model.learn(total_timesteps=1000000)
model_name="ppo'LunarLander-v2"
model.save(model_name)
# Out:
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 89.2     |
# |    ep_rew_mean     | -170     |
# | time/              |          |
# |    fps             | 3578     |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 16384    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 91.5        |
# |    ep_rew_mean          | -140        |
# | time/                   |             |
# |    fps                  | 2285        |
# |    iterations           | 2           |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.006909267 |
# |    clip_fraction        | 0.0482      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | 0.00196     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.22e+03    |
# |    n_updates            | 4           |
# |    policy_gradient_loss | -0.00633    |
# |    value_loss           | 4.01e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 105         |
# |    ep_rew_mean          | -131        |
# | time/                   |             |
# |    fps                  | 2131        |
# |    iterations           | 3           |
# |    time_elapsed         | 23          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.008035058 |
# |    clip_fraction        | 0.0448      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -0.00183    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 608         |
# |    n_updates            | 8           |
# |    policy_gradient_loss | -0.00502    |
# |    value_loss           | 1.82e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 96.4        |
# |    ep_rew_mean          | -108        |
# | time/                   |             |
# |    fps                  | 2045        |
# |    iterations           | 4           |
# |    time_elapsed         | 32          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.008020663 |
# |    clip_fraction        | 0.0464      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | 0.00335     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 332         |
# |    n_updates            | 12          |
# |    policy_gradient_loss | -0.00457    |
# |    value_loss           | 1.39e+03    |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 95.4        |
# |    ep_rew_mean          | -98.6       |
# | time/                   |             |
# |    fps                  | 1982        |
# |    iterations           | 5           |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 81920       |
# | train/                  |             |
# |    approx_kl            | 0.008401399 |
# |    clip_fraction        | 0.0867      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -0.00952    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 194         |
# |    n_updates            | 16          |
# |    policy_gradient_loss | -0.00316    |
# |    value_loss           | 672         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 109         |
# |    ep_rew_mean          | -85.5       |
# | time/                   |             |
# |    fps                  | 1936        |
# |    iterations           | 6           |
# |    time_elapsed         | 50          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.006788112 |
# |    clip_fraction        | 0.0525      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.33       |
# |    explained_variance   | 0.196       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 320         |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00432    |
# |    value_loss           | 700         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 107         |
# |    ep_rew_mean          | -62.5       |
# | time/                   |             |
# |    fps                  | 1917        |
# |    iterations           | 7           |
# |    time_elapsed         | 59          |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.008062734 |
# |    clip_fraction        | 0.0503      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.385       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 298         |
# |    n_updates            | 24          |
# |    policy_gradient_loss | -0.00572    |
# |    value_loss           | 480         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 109         |
# |    ep_rew_mean          | -44.6       |
# | time/                   |             |
# |    fps                  | 1884        |
# |    iterations           | 8           |
# |    time_elapsed         | 69          |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.011816002 |
# |    clip_fraction        | 0.139       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | -0.0644     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 186         |
# |    n_updates            | 28          |
# |    policy_gradient_loss | -0.0061     |
# |    value_loss           | 391         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 113         |
# |    ep_rew_mean          | -40.2       |
# | time/                   |             |
# |    fps                  | 1860        |
# |    iterations           | 9           |
# |    time_elapsed         | 79          |
# |    total_timesteps      | 147456      |
# | train/                  |             |
# |    approx_kl            | 0.011684726 |
# |    clip_fraction        | 0.0753      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | -1.82e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 145         |
# |    n_updates            | 32          |
# |    policy_gradient_loss | -0.00351    |
# |    value_loss           | 340         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 135         |
# |    ep_rew_mean          | -19.5       |
# | time/                   |             |
# |    fps                  | 1813        |
# |    iterations           | 10          |
# |    time_elapsed         | 90          |
# |    total_timesteps      | 163840      |
# | train/                  |             |
# |    approx_kl            | 0.011866378 |
# |    clip_fraction        | 0.096       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | -2.47e-05   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 222         |
# |    n_updates            | 36          |
# |    policy_gradient_loss | -0.00426    |
# |    value_loss           | 435         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 166        |
# |    ep_rew_mean          | -24.2      |
# | time/                   |            |
# |    fps                  | 1749       |
# |    iterations           | 11         |
# |    time_elapsed         | 102        |
# |    total_timesteps      | 180224     |
# | train/                  |            |
# |    approx_kl            | 0.00839575 |
# |    clip_fraction        | 0.0391     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.18      |
# |    explained_variance   | -0.000773  |
# |    learning_rate        | 0.0003     |
# |    loss                 | 235        |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0014    |
# |    value_loss           | 476        |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 214         |
# |    ep_rew_mean          | -17.1       |
# | time/                   |             |
# |    fps                  | 1615        |
# |    iterations           | 12          |
# |    time_elapsed         | 121         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.008045865 |
# |    clip_fraction        | 0.0586      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | -3.81e-06   |
# |    learning_rate        | 0.0003      |
# |    loss                 | 248         |
# |    n_updates            | 44          |
# |    policy_gradient_loss | -0.00337    |
# |    value_loss           | 593         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 325          |
# |    ep_rew_mean          | -5.54        |
# | time/                   |              |
# |    fps                  | 1459         |
# |    iterations           | 13           |
# |    time_elapsed         | 145          |
# |    total_timesteps      | 212992       |
# | train/                  |              |
# |    approx_kl            | 0.0072905878 |
# |    clip_fraction        | 0.0822       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 1.01e-05     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 156          |
# |    n_updates            | 48           |
# |    policy_gradient_loss | -0.0019      |
# |    value_loss           | 564          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 410          |
# |    ep_rew_mean          | -2.78        |
# | time/                   |              |
# |    fps                  | 1389         |
# |    iterations           | 14           |
# |    time_elapsed         | 165          |
# |    total_timesteps      | 229376       |
# | train/                  |              |
# |    approx_kl            | 0.0049495166 |
# |    clip_fraction        | 0.00751      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.24        |
# |    explained_variance   | 0.000335     |
# |    learning_rate        | 0.0003       |
# |    loss                 | 204          |
# |    n_updates            | 52           |
# |    policy_gradient_loss | -0.00198     |
# |    value_loss           | 363          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 418          |
# |    ep_rew_mean          | -8.41        |
# | time/                   |              |
# |    fps                  | 1324         |
# |    iterations           | 15           |
# |    time_elapsed         | 185          |
# |    total_timesteps      | 245760       |
# | train/                  |              |
# |    approx_kl            | 0.0044353805 |
# |    clip_fraction        | 0.0128       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.21        |
# |    explained_variance   | 0.262        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 183          |
# |    n_updates            | 56           |
# |    policy_gradient_loss | -0.00178     |
# |    value_loss           | 435          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 466         |
# |    ep_rew_mean          | -9.71       |
# | time/                   |             |
# |    fps                  | 1258        |
# |    iterations           | 16          |
# |    time_elapsed         | 208         |
# |    total_timesteps      | 262144      |
# | train/                  |             |
# |    approx_kl            | 0.003160052 |
# |    clip_fraction        | 0.0105      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.21       |
# |    explained_variance   | 0.42        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 317         |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.00138    |
# |    value_loss           | 320         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 558         |
# |    ep_rew_mean          | -6.62       |
# | time/                   |             |
# |    fps                  | 1197        |
# |    iterations           | 17          |
# |    time_elapsed         | 232         |
# |    total_timesteps      | 278528      |
# | train/                  |             |
# |    approx_kl            | 0.006751471 |
# |    clip_fraction        | 0.0365      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.22       |
# |    explained_variance   | 0.541       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 112         |
# |    n_updates            | 64          |
# |    policy_gradient_loss | -0.00265    |
# |    value_loss           | 233         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 603          |
# |    ep_rew_mean          | 7.5          |
# | time/                   |              |
# |    fps                  | 1158         |
# |    iterations           | 18           |
# |    time_elapsed         | 254          |
# |    total_timesteps      | 294912       |
# | train/                  |              |
# |    approx_kl            | 0.0060677743 |
# |    clip_fraction        | 0.0897       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.22        |
# |    explained_variance   | 0.683        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 42.9         |
# |    n_updates            | 68           |
# |    policy_gradient_loss | -0.00249     |
# |    value_loss           | 149          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 657          |
# |    ep_rew_mean          | 9.13         |
# | time/                   |              |
# |    fps                  | 1123         |
# |    iterations           | 19           |
# |    time_elapsed         | 277          |
# |    total_timesteps      | 311296       |
# | train/                  |              |
# |    approx_kl            | 0.0047370465 |
# |    clip_fraction        | 0.0216       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.2         |
# |    explained_variance   | 0.715        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 33.2         |
# |    n_updates            | 72           |
# |    policy_gradient_loss | -0.00127     |
# |    value_loss           | 157          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 724         |
# |    ep_rew_mean          | 17.8        |
# | time/                   |             |
# |    fps                  | 1087        |
# |    iterations           | 20          |
# |    time_elapsed         | 301         |
# |    total_timesteps      | 327680      |
# | train/                  |             |
# |    approx_kl            | 0.008103146 |
# |    clip_fraction        | 0.0399      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.15       |
# |    explained_variance   | 0.757       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 111         |
# |    n_updates            | 76          |
# |    policy_gradient_loss | -0.00301    |
# |    value_loss           | 182         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 731          |
# |    ep_rew_mean          | 24.8         |
# | time/                   |              |
# |    fps                  | 1063         |
# |    iterations           | 21           |
# |    time_elapsed         | 323          |
# |    total_timesteps      | 344064       |
# | train/                  |              |
# |    approx_kl            | 0.0051100384 |
# |    clip_fraction        | 0.0318       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.18        |
# |    explained_variance   | 0.853        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 50.4         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00223     |
# |    value_loss           | 92.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 755         |
# |    ep_rew_mean          | 30.1        |
# | time/                   |             |
# |    fps                  | 1040        |
# |    iterations           | 22          |
# |    time_elapsed         | 346         |
# |    total_timesteps      | 360448      |
# | train/                  |             |
# |    approx_kl            | 0.004325049 |
# |    clip_fraction        | 0.0235      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.16       |
# |    explained_variance   | 0.785       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 69          |
# |    n_updates            | 84          |
# |    policy_gradient_loss | -0.00181    |
# |    value_loss           | 161         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 785         |
# |    ep_rew_mean          | 36.1        |
# | time/                   |             |
# |    fps                  | 1020        |
# |    iterations           | 23          |
# |    time_elapsed         | 369         |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.004381584 |
# |    clip_fraction        | 0.032       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.804       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 54.3        |
# |    n_updates            | 88          |
# |    policy_gradient_loss | -0.000968   |
# |    value_loss           | 120         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 825         |
# |    ep_rew_mean          | 52.7        |
# | time/                   |             |
# |    fps                  | 1006        |
# |    iterations           | 24          |
# |    time_elapsed         | 390         |
# |    total_timesteps      | 393216      |
# | train/                  |             |
# |    approx_kl            | 0.004482054 |
# |    clip_fraction        | 0.026       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.18       |
# |    explained_variance   | 0.85        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 64          |
# |    n_updates            | 92          |
# |    policy_gradient_loss | -0.00129    |
# |    value_loss           | 114         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 837          |
# |    ep_rew_mean          | 63.7         |
# | time/                   |              |
# |    fps                  | 991          |
# |    iterations           | 25           |
# |    time_elapsed         | 413          |
# |    total_timesteps      | 409600       |
# | train/                  |              |
# |    approx_kl            | 0.0050059403 |
# |    clip_fraction        | 0.0428       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 0.909        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 37.3         |
# |    n_updates            | 96           |
# |    policy_gradient_loss | -0.00194     |
# |    value_loss           | 67.8         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 846          |
# |    ep_rew_mean          | 73.2         |
# | time/                   |              |
# |    fps                  | 977          |
# |    iterations           | 26           |
# |    time_elapsed         | 435          |
# |    total_timesteps      | 425984       |
# | train/                  |              |
# |    approx_kl            | 0.0057779667 |
# |    clip_fraction        | 0.0592       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.16        |
# |    explained_variance   | 0.898        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 34.2         |
# |    n_updates            | 100          |
# |    policy_gradient_loss | -0.00129     |
# |    value_loss           | 74.8         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 824         |
# |    ep_rew_mean          | 82.9        |
# | time/                   |             |
# |    fps                  | 968         |
# |    iterations           | 27          |
# |    time_elapsed         | 456         |
# |    total_timesteps      | 442368      |
# | train/                  |             |
# |    approx_kl            | 0.003907612 |
# |    clip_fraction        | 0.0336      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.891       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 42.8        |
# |    n_updates            | 104         |
# |    policy_gradient_loss | -0.00101    |
# |    value_loss           | 84.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 840         |
# |    ep_rew_mean          | 89.6        |
# | time/                   |             |
# |    fps                  | 960         |
# |    iterations           | 28          |
# |    time_elapsed         | 477         |
# |    total_timesteps      | 458752      |
# | train/                  |             |
# |    approx_kl            | 0.006459521 |
# |    clip_fraction        | 0.0273      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.12       |
# |    explained_variance   | 0.897       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 30.7        |
# |    n_updates            | 108         |
# |    policy_gradient_loss | -0.00107    |
# |    value_loss           | 89          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 861         |
# |    ep_rew_mean          | 94.4        |
# | time/                   |             |
# |    fps                  | 950         |
# |    iterations           | 29          |
# |    time_elapsed         | 499         |
# |    total_timesteps      | 475136      |
# | train/                  |             |
# |    approx_kl            | 0.008175056 |
# |    clip_fraction        | 0.0627      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.07       |
# |    explained_variance   | 0.943       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 41.2        |
# |    n_updates            | 112         |
# |    policy_gradient_loss | -0.00205    |
# |    value_loss           | 50.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 868          |
# |    ep_rew_mean          | 96.2         |
# | time/                   |              |
# |    fps                  | 943          |
# |    iterations           | 30           |
# |    time_elapsed         | 521          |
# |    total_timesteps      | 491520       |
# | train/                  |              |
# |    approx_kl            | 0.0038504265 |
# |    clip_fraction        | 0.0259       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.07        |
# |    explained_variance   | 0.941        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 59.2         |
# |    n_updates            | 116          |
# |    policy_gradient_loss | -0.000876    |
# |    value_loss           | 55.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 887          |
# |    ep_rew_mean          | 99.9         |
# | time/                   |              |
# |    fps                  | 930          |
# |    iterations           | 31           |
# |    time_elapsed         | 545          |
# |    total_timesteps      | 507904       |
# | train/                  |              |
# |    approx_kl            | 0.0044140117 |
# |    clip_fraction        | 0.0267       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.04        |
# |    explained_variance   | 0.959        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.28         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.000488    |
# |    value_loss           | 33.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 920          |
# |    ep_rew_mean          | 105          |
# | time/                   |              |
# |    fps                  | 923          |
# |    iterations           | 32           |
# |    time_elapsed         | 567          |
# |    total_timesteps      | 524288       |
# | train/                  |              |
# |    approx_kl            | 0.0059251315 |
# |    clip_fraction        | 0.0442       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.981        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.17         |
# |    n_updates            | 124          |
# |    policy_gradient_loss | -0.00172     |
# |    value_loss           | 14.7         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 915          |
# |    ep_rew_mean          | 106          |
# | time/                   |              |
# |    fps                  | 914          |
# |    iterations           | 33           |
# |    time_elapsed         | 591          |
# |    total_timesteps      | 540672       |
# | train/                  |              |
# |    approx_kl            | 0.0074567185 |
# |    clip_fraction        | 0.0418       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.999       |
# |    explained_variance   | 0.96         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.14         |
# |    n_updates            | 128          |
# |    policy_gradient_loss | -0.00121     |
# |    value_loss           | 35.4         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 921        |
# |    ep_rew_mean          | 110        |
# | time/                   |            |
# |    fps                  | 907        |
# |    iterations           | 34         |
# |    time_elapsed         | 614        |
# |    total_timesteps      | 557056     |
# | train/                  |            |
# |    approx_kl            | 0.00483393 |
# |    clip_fraction        | 0.0321     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.991     |
# |    explained_variance   | 0.963      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 6.75       |
# |    n_updates            | 132        |
# |    policy_gradient_loss | -0.0025    |
# |    value_loss           | 36.3       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 933          |
# |    ep_rew_mean          | 113          |
# | time/                   |              |
# |    fps                  | 896          |
# |    iterations           | 35           |
# |    time_elapsed         | 639          |
# |    total_timesteps      | 573440       |
# | train/                  |              |
# |    approx_kl            | 0.0042403266 |
# |    clip_fraction        | 0.0505       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.979       |
# |    explained_variance   | 0.983        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.86         |
# |    n_updates            | 136          |
# |    policy_gradient_loss | -0.00129     |
# |    value_loss           | 15.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 926          |
# |    ep_rew_mean          | 115          |
# | time/                   |              |
# |    fps                  | 885          |
# |    iterations           | 36           |
# |    time_elapsed         | 666          |
# |    total_timesteps      | 589824       |
# | train/                  |              |
# |    approx_kl            | 0.0047269035 |
# |    clip_fraction        | 0.0568       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.03        |
# |    explained_variance   | 0.986        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 15.3         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.00141     |
# |    value_loss           | 13.4         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 926          |
# |    ep_rew_mean          | 114          |
# | time/                   |              |
# |    fps                  | 875          |
# |    iterations           | 37           |
# |    time_elapsed         | 692          |
# |    total_timesteps      | 606208       |
# | train/                  |              |
# |    approx_kl            | 0.0040336885 |
# |    clip_fraction        | 0.0453       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1           |
# |    explained_variance   | 0.972        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.1          |
# |    n_updates            | 144          |
# |    policy_gradient_loss | -0.000747    |
# |    value_loss           | 29.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 953          |
# |    ep_rew_mean          | 121          |
# | time/                   |              |
# |    fps                  | 868          |
# |    iterations           | 38           |
# |    time_elapsed         | 717          |
# |    total_timesteps      | 622592       |
# | train/                  |              |
# |    approx_kl            | 0.0047420533 |
# |    clip_fraction        | 0.0339       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.993       |
# |    explained_variance   | 0.991        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.7          |
# |    n_updates            | 148          |
# |    policy_gradient_loss | -0.00053     |
# |    value_loss           | 6.93         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 972          |
# |    ep_rew_mean          | 127          |
# | time/                   |              |
# |    fps                  | 862          |
# |    iterations           | 39           |
# |    time_elapsed         | 741          |
# |    total_timesteps      | 638976       |
# | train/                  |              |
# |    approx_kl            | 0.0050821183 |
# |    clip_fraction        | 0.0299       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.954       |
# |    explained_variance   | 0.994        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.93         |
# |    n_updates            | 152          |
# |    policy_gradient_loss | -0.00161     |
# |    value_loss           | 5.94         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 980          |
# |    ep_rew_mean          | 129          |
# | time/                   |              |
# |    fps                  | 855          |
# |    iterations           | 40           |
# |    time_elapsed         | 766          |
# |    total_timesteps      | 655360       |
# | train/                  |              |
# |    approx_kl            | 0.0042070774 |
# |    clip_fraction        | 0.0433       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.93        |
# |    explained_variance   | 0.996        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.925        |
# |    n_updates            | 156          |
# |    policy_gradient_loss | -0.00187     |
# |    value_loss           | 4.3          |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 980         |
# |    ep_rew_mean          | 130         |
# | time/                   |             |
# |    fps                  | 851         |
# |    iterations           | 41          |
# |    time_elapsed         | 788         |
# |    total_timesteps      | 671744      |
# | train/                  |             |
# |    approx_kl            | 0.004084287 |
# |    clip_fraction        | 0.0359      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.875      |
# |    explained_variance   | 0.994       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.05        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00169    |
# |    value_loss           | 5.13        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 967         |
# |    ep_rew_mean          | 135         |
# | time/                   |             |
# |    fps                  | 849         |
# |    iterations           | 42          |
# |    time_elapsed         | 810         |
# |    total_timesteps      | 688128      |
# | train/                  |             |
# |    approx_kl            | 0.003049734 |
# |    clip_fraction        | 0.0182      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.893      |
# |    explained_variance   | 0.982       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.08        |
# |    n_updates            | 164         |
# |    policy_gradient_loss | 0.000194    |
# |    value_loss           | 18.8        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 954          |
# |    ep_rew_mean          | 140          |
# | time/                   |              |
# |    fps                  | 847          |
# |    iterations           | 43           |
# |    time_elapsed         | 831          |
# |    total_timesteps      | 704512       |
# | train/                  |              |
# |    approx_kl            | 0.0042527216 |
# |    clip_fraction        | 0.0473       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.855       |
# |    explained_variance   | 0.931        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.78         |
# |    n_updates            | 168          |
# |    policy_gradient_loss | -0.0021      |
# |    value_loss           | 100          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 954          |
# |    ep_rew_mean          | 141          |
# | time/                   |              |
# |    fps                  | 843          |
# |    iterations           | 44           |
# |    time_elapsed         | 854          |
# |    total_timesteps      | 720896       |
# | train/                  |              |
# |    approx_kl            | 0.0039448026 |
# |    clip_fraction        | 0.0401       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.839       |
# |    explained_variance   | 0.953        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 172          |
# |    n_updates            | 172          |
# |    policy_gradient_loss | -0.000147    |
# |    value_loss           | 60.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 935          |
# |    ep_rew_mean          | 146          |
# | time/                   |              |
# |    fps                  | 840          |
# |    iterations           | 45           |
# |    time_elapsed         | 877          |
# |    total_timesteps      | 737280       |
# | train/                  |              |
# |    approx_kl            | 0.0044554113 |
# |    clip_fraction        | 0.0444       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.828       |
# |    explained_variance   | 0.994        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.863        |
# |    n_updates            | 176          |
# |    policy_gradient_loss | 0.000487     |
# |    value_loss           | 3.64         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 890         |
# |    ep_rew_mean          | 142         |
# | time/                   |             |
# |    fps                  | 838         |
# |    iterations           | 46          |
# |    time_elapsed         | 898         |
# |    total_timesteps      | 753664      |
# | train/                  |             |
# |    approx_kl            | 0.006145931 |
# |    clip_fraction        | 0.0577      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.798      |
# |    explained_variance   | 0.91        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 54          |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.00301    |
# |    value_loss           | 129         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 880          |
# |    ep_rew_mean          | 146          |
# | time/                   |              |
# |    fps                  | 836          |
# |    iterations           | 47           |
# |    time_elapsed         | 920          |
# |    total_timesteps      | 770048       |
# | train/                  |              |
# |    approx_kl            | 0.0030512558 |
# |    clip_fraction        | 0.0238       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.816       |
# |    explained_variance   | 0.927        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.5         |
# |    n_updates            | 184          |
# |    policy_gradient_loss | -0.000215    |
# |    value_loss           | 87.5         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 862         |
# |    ep_rew_mean          | 159         |
# | time/                   |             |
# |    fps                  | 834         |
# |    iterations           | 48          |
# |    time_elapsed         | 942         |
# |    total_timesteps      | 786432      |
# | train/                  |             |
# |    approx_kl            | 0.004388522 |
# |    clip_fraction        | 0.0536      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.763      |
# |    explained_variance   | 0.922       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 13.7        |
# |    n_updates            | 188         |
# |    policy_gradient_loss | -0.00251    |
# |    value_loss           | 101         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 774         |
# |    ep_rew_mean          | 174         |
# | time/                   |             |
# |    fps                  | 834         |
# |    iterations           | 49          |
# |    time_elapsed         | 962         |
# |    total_timesteps      | 802816      |
# | train/                  |             |
# |    approx_kl            | 0.004927462 |
# |    clip_fraction        | 0.0693      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.73       |
# |    explained_variance   | 0.864       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 252         |
# |    n_updates            | 192         |
# |    policy_gradient_loss | -0.00311    |
# |    value_loss           | 210         |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 709         |
# |    ep_rew_mean          | 207         |
# | time/                   |             |
# |    fps                  | 834         |
# |    iterations           | 50          |
# |    time_elapsed         | 981         |
# |    total_timesteps      | 819200      |
# | train/                  |             |
# |    approx_kl            | 0.003820506 |
# |    clip_fraction        | 0.0444      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.717      |
# |    explained_variance   | 0.797       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 127         |
# |    n_updates            | 196         |
# |    policy_gradient_loss | -0.00293    |
# |    value_loss           | 306         |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 575        |
# |    ep_rew_mean          | 226        |
# | time/                   |            |
# |    fps                  | 835        |
# |    iterations           | 51         |
# |    time_elapsed         | 999        |
# |    total_timesteps      | 835584     |
# | train/                  |            |
# |    approx_kl            | 0.00568207 |
# |    clip_fraction        | 0.0547     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.747     |
# |    explained_variance   | 0.775      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 184        |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.00243   |
# |    value_loss           | 277        |
# ----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 468       |
# |    ep_rew_mean          | 240       |
# | time/                   |           |
# |    fps                  | 839       |
# |    iterations           | 52        |
# |    time_elapsed         | 1015      |
# |    total_timesteps      | 851968    |
# | train/                  |           |
# |    approx_kl            | 0.0063891 |
# |    clip_fraction        | 0.0401    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.75     |
# |    explained_variance   | 0.715     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 110       |
# |    n_updates            | 204       |
# |    policy_gradient_loss | -0.0025   |
# |    value_loss           | 261       |
# ---------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 404         |
# |    ep_rew_mean          | 247         |
# | time/                   |             |
# |    fps                  | 840         |
# |    iterations           | 53          |
# |    time_elapsed         | 1032        |
# |    total_timesteps      | 868352      |
# | train/                  |             |
# |    approx_kl            | 0.005312078 |
# |    clip_fraction        | 0.064       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.822      |
# |    explained_variance   | 0.744       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 45.9        |
# |    n_updates            | 208         |
# |    policy_gradient_loss | -0.00152    |
# |    value_loss           | 112         |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 388          |
# |    ep_rew_mean          | 254          |
# | time/                   |              |
# |    fps                  | 840          |
# |    iterations           | 54           |
# |    time_elapsed         | 1052         |
# |    total_timesteps      | 884736       |
# | train/                  |              |
# |    approx_kl            | 0.0052633835 |
# |    clip_fraction        | 0.0466       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.843       |
# |    explained_variance   | 0.738        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 27.9         |
# |    n_updates            | 212          |
# |    policy_gradient_loss | -0.000491    |
# |    value_loss           | 100          |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 378          |
# |    ep_rew_mean          | 259          |
# | time/                   |              |
# |    fps                  | 844          |
# |    iterations           | 55           |
# |    time_elapsed         | 1067         |
# |    total_timesteps      | 901120       |
# | train/                  |              |
# |    approx_kl            | 0.0030767007 |
# |    clip_fraction        | 0.0302       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.82        |
# |    explained_variance   | 0.878        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 20.2         |
# |    n_updates            | 216          |
# |    policy_gradient_loss | -0.000381    |
# |    value_loss           | 75.5         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 368          |
# |    ep_rew_mean          | 256          |
# | time/                   |              |
# |    fps                  | 848          |
# |    iterations           | 56           |
# |    time_elapsed         | 1081         |
# |    total_timesteps      | 917504       |
# | train/                  |              |
# |    approx_kl            | 0.0074132523 |
# |    clip_fraction        | 0.047        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.854       |
# |    explained_variance   | 0.943        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 19.2         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00111     |
# |    value_loss           | 48.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 344          |
# |    ep_rew_mean          | 257          |
# | time/                   |              |
# |    fps                  | 852          |
# |    iterations           | 57           |
# |    time_elapsed         | 1095         |
# |    total_timesteps      | 933888       |
# | train/                  |              |
# |    approx_kl            | 0.0050715525 |
# |    clip_fraction        | 0.043        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.841       |
# |    explained_variance   | 0.894        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.03         |
# |    n_updates            | 224          |
# |    policy_gradient_loss | -0.000345    |
# |    value_loss           | 20.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 391         |
# |    ep_rew_mean          | 255         |
# | time/                   |             |
# |    fps                  | 849         |
# |    iterations           | 58          |
# |    time_elapsed         | 1118        |
# |    total_timesteps      | 950272      |
# | train/                  |             |
# |    approx_kl            | 0.006136895 |
# |    clip_fraction        | 0.0315      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.858      |
# |    explained_variance   | 0.796       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 23.8        |
# |    n_updates            | 228         |
# |    policy_gradient_loss | 0.000162    |
# |    value_loss           | 67.1        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 464          |
# |    ep_rew_mean          | 246          |
# | time/                   |              |
# |    fps                  | 851          |
# |    iterations           | 59           |
# |    time_elapsed         | 1135         |
# |    total_timesteps      | 966656       |
# | train/                  |              |
# |    approx_kl            | 0.0034361791 |
# |    clip_fraction        | 0.0282       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.72        |
# |    explained_variance   | 0.939        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.17         |
# |    n_updates            | 232          |
# |    policy_gradient_loss | -0.00051     |
# |    value_loss           | 20.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 527          |
# |    ep_rew_mean          | 245          |
# | time/                   |              |
# |    fps                  | 853          |
# |    iterations           | 60           |
# |    time_elapsed         | 1151         |
# |    total_timesteps      | 983040       |
# | train/                  |              |
# |    approx_kl            | 0.0025840038 |
# |    clip_fraction        | 0.026        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.735       |
# |    explained_variance   | 0.964        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.2          |
# |    n_updates            | 236          |
# |    policy_gradient_loss | -0.000542    |
# |    value_loss           | 17.9         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 459          |
# |    ep_rew_mean          | 253          |
# | time/                   |              |
# |    fps                  | 856          |
# |    iterations           | 61           |
# |    time_elapsed         | 1166         |
# |    total_timesteps      | 999424       |
# | train/                  |              |
# |    approx_kl            | 0.0041455673 |
# |    clip_fraction        | 0.036        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.733       |
# |    explained_variance   | 0.979        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 10.1         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00212     |
# |    value_loss           | 22.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 382         |
# |    ep_rew_mean          | 259         |
# | time/                   |             |
# |    fps                  | 860         |
# |    iterations           | 62          |
# |    time_elapsed         | 1180        |
# |    total_timesteps      | 1015808     |
# | train/                  |             |
# |    approx_kl            | 0.005901519 |
# |    clip_fraction        | 0.0688      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.776      |
# |    explained_variance   | 0.981       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.3         |
# |    n_updates            | 244         |
# |    policy_gradient_loss | -0.00222    |
# |    value_loss           | 21.3        |
# -----------------------------------------

# %%
#@title
eval_env = Monitor(gym.make("LunarLander-v2", render_mode='rgb_array'))
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)
print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# mean_reward=268.44 +/- 18.682940149588696

# %%
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
import gymnasium as gym
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.env_util import make_vec_env

from huggingface_sb3 import package_to_hub

repo_id="gokulan006/ppo-LunarLander-v2"

env_id="LunarLander-v2"
model_architecture="PPO"
commit_message = "Upload PPO LunarLander-v2 trained agent"
eval_env=DummyVecEnv([lambda: gym.make(env_id,render_mode="rgb_array")])
package_to_hub(model=model,
               model_name=model_name,
               model_architecture=model_architecture,
               env_id=env_id,
               eval_env=eval_env,
               repo_id=repo_id,
               commit_message=commit_message)
# Out:
# /usr/local/lib/python3.11/dist-packages/stable_baselines3/common/evaluation.py:67: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# policy.pth:   0%|          | 0.00/43.8k [00:00<?, ?B/s]
# pytorch_variables.pth:   0%|          | 0.00/864 [00:00<?, ?B/s]
# policy.optimizer.pth:   0%|          | 0.00/88.4k [00:00<?, ?B/s]
# Upload 5 LFS files:   0%|          | 0/5 [00:00<?, ?it/s]
# ppo'LunarLander-v2.zip:   0%|          | 0.00/148k [00:00<?, ?B/s]
# replay.mp4:   0%|          | 0.00/153k [00:00<?, ?B/s]
# CommitInfo(commit_url='https://huggingface.co/gokulan006/ppo-LunarLander-v2/commit/c2872eec958242a92f3d5ba0bc93f2c70361f7ec', commit_message='Upload PPO LunarLander-v2 trained agent', commit_description='', oid='c2872eec958242a92f3d5ba0bc93f2c70361f7ec', pr_url=None, repo_url=RepoUrl('https://huggingface.co/gokulan006/ppo-LunarLander-v2', endpoint='https://huggingface.co', repo_type='model', repo_id='gokulan006/ppo-LunarLander-v2'), pr_revision=None, pr_num=None)

# %%
# !pip install shimmy

# %%
from huggingface_sb3 import load_from_hub
repo_id = "Classroom-workshop/assignment2-omar" # The repo_id
filename = "ppo-LunarLander-v2.zip" # The model filename.zip

# When the model was trained on Python 3.8 the pickle protocol is 5
# But Python 3.6, 3.7 use protocol 4
# In order to get compatibility we need to:
# 1. Install pickle5 (we done it at the beginning of the colab)
# 2. Create a custom empty object we pass as parameter to PPO.load()
custom_objects = {
            "learning_rate": 0.0,
            "lr_schedule": lambda _: 0.0,
            "clip_range": lambda _: 0.0,
}

checkpoint = load_from_hub(repo_id, filename)
model = PPO.load(checkpoint, custom_objects=custom_objects, print_system_info=True)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ppo-LunarLander-v2.zip:   0%|          | 0.00/146k [00:00<?, ?B/s]
# == CURRENT SYSTEM INFO ==
# - OS: Linux-6.1.85+-x86_64-with-glibc2.35 # 1 SMP PREEMPT_DYNAMIC Thu Jun 27 21:05:47 UTC 2024
# - Python: 3.11.11
# - Stable-Baselines3: 2.0.0a5
# - PyTorch: 2.5.1+cu124
# - GPU Enabled: True
# - Numpy: 1.26.4
# - Cloudpickle: 3.1.1
# - Gymnasium: 0.28.1
# - OpenAI Gym: 0.25.2
#
# == SAVED MODEL SYSTEM INFO ==
# OS: Linux-5.4.188+-x86_64-with-Ubuntu-18.04-bionic #1 SMP Sun Apr 24 10:03:06 PDT 2022
# Python: 3.7.13
# Stable-Baselines3: 1.5.0
# PyTorch: 1.11.0+cu113
# GPU Enabled: True
# Numpy: 1.21.6
# Gym: 0.21.0
# /usr/local/lib/python3.11/dist-packages/stable_baselines3/common/save_util.py:437: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   th_object = th.load(file_content, map_location=device)
# /usr/local/lib/python3.11/dist-packages/stable_baselines3/common/vec_env/patch_gym.py:95: UserWarning: You loaded a model that was trained using OpenAI Gym. We strongly recommend transitioning to Gymnasium by saving that model again.
#   warnings.warn(

# %%
#@title
import gymnasium as gym
eval_env = Monitor(gym.make("LunarLander-v2"))
mean_reward, std_reward = evaluate_policy(model, eval_env, n_eval_episodes=10, deterministic=True)
print(f"mean_reward={mean_reward:.2f} +/- {std_reward}")
# Out:
# /usr/local/lib/python3.11/dist-packages/pygame/pkgdata.py:25: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import resource_stream, resource_exists
# /usr/local/lib/python3.11/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.11/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.cloud')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.11/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('sphinxcontrib')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# mean_reward=294.76 +/- 15.484523563379705
